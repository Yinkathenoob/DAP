# %% [markdown]
# <center><img src="MKn_Staffelter_Hof.jpeg" alt="Picture of old business"</center>
# <!--Image Credit: Martin Kraft https://commons.wikimedia.org/wiki/File:MKn_Staffelter_Hof.jpg -->

# %% [markdown]
# Staffelter Hof Winery is Germany's oldest business, established in 862 under the Carolingian dynasty. It has continued to serve customers through dramatic changes in Europe, such as the Holy Roman Empire, the Ottoman Empire, and both world wars. What characteristics enable a business to stand the test of time?
#
# To help answer this question, BusinessFinancing.co.uk researched the oldest company still in business in **almost** every country and compiled the results into several CSV files. This dataset has been cleaned.
#
# Having useful information in different files is a common problem. While it's better to keep different types of data separate for data storage, you'll want all the data in one place for analysis. You'll use joining and data manipulation to work with this data and better understand the world's oldest businesses.
#
# ## The Data
# `data/businesses.csv` and `data/new_businesses.csv`
# |Column|Description|
# |------|-----------|
# |`business`|Name of the business (varchar)|
# |`year_founded`|Year the business was founded (int)|
# |`category_code`|Code for the business category (varchar)|
# |`country_code`|ISO 3166-1 three-letter country code (char)|
#
# `data/countries.csv`
# |Column|Description|
# |------|-----------|
# |`country_code`|ISO 3166-1 three-letter country code (varchar)|
# |`country`|Name of the country (varchar)|
# |`continent`|Name of the continent the country exists in (varchar)|
#
# `data/categories.csv`
# |Column|Description|
# |------|-----------|
# |`category_code`|Code for the business category (varchar)|
# |`category`|Description of the business category (varchar)|

# %% [markdown]
# ### Understand the factors that help a business be timeless by answering these questions:
#
# #### 1. What is the oldest business on each continent? Save your answer as a DataFrame called oldest_business_continent with four columns: continent, country, business, and year_founded in any order.
#
# #### 2. How many countries per continent lack data on the oldest businesses? Does including new_businesses change this? Count the number of countries per continent missing business data, including new_businesses, and store the results in a DataFrame named count_missing with columns for the continent and the count.
#
# #### 3. Which business categories are best suited to last many years, and on what continent are they? Create a DataFrame called oldest_by_continent_category that stores the oldest founding year for each continent and category combination. It should contain three columns: continent, category, and year_founded, in that order.

# %%
# Import necessary libraries
import pandas as pd

# Load the data
businesses = pd.read_csv("data/businesses.csv")
new_businesses = pd.read_csv("data/new_businesses.csv")
countries = pd.read_csv("data/countries.csv")
categories = pd.read_csv("data/categories.csv")

# %%
print(businesses.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163 entries, 0 to 162
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   business       163 non-null    object
#  1   year_founded   163 non-null    int64
#  2   category_code  163 non-null    object
#  3   country_code   163 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 5.2+ KB
# None

# %%
print(new_businesses.head())
# Out:
#                     business  year_founded category_code country_code
# 0                 Fiji Times          1869         CAT13          FJI
# 1  J. Armando Bermúdez & Co.          1852          CAT9          DOM

# %%
print(countries.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country_code  195 non-null    object
#  1   country       195 non-null    object
#  2   continent     195 non-null    object
# dtypes: object(3)
# memory usage: 4.7+ KB
# None

# %%
print(categories.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   category_code  19 non-null     object
#  1   category       19 non-null     object
# dtypes: object(2)
# memory usage: 432.0+ bytes
# None

# %%
businesses_merged = pd.concat([businesses, new_businesses], ignore_index=True)
print(businesses_merged.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   business       165 non-null    object
#  1   year_founded   165 non-null    int64
#  2   category_code  165 non-null    object
#  3   country_code   165 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 5.3+ KB
# None

# %%
businesses_merged = businesses_merged.merge(categories, on = 'category_code')

print(businesses_merged.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   business       165 non-null    object
#  1   year_founded   165 non-null    int64
#  2   category_code  165 non-null    object
#  3   country_code   165 non-null    object
#  4   category       165 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 6.6+ KB
# None

# %%
businesses_merged = businesses_merged.merge(countries, on = 'country_code')
print(businesses_merged.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   business       165 non-null    object
#  1   year_founded   165 non-null    int64
#  2   category_code  165 non-null    object
#  3   country_code   165 non-null    object
#  4   category       165 non-null    object
#  5   country        165 non-null    object
#  6   continent      165 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 9.1+ KB
# None

# %% [markdown]
# #### Question 1

# %%
sorted_by_cont = businesses_merged.groupby(['continent', 'year_founded'], as_index=False)['business'].sum()

print(sorted_by_cont.tail(30))
# Out:
#          continent  year_founded                              business
# 122  North America          1638                    Shirley Plantation
# 123  North America          1670                  Hudson's Bay Company
# 124  North America          1703                         Mount Gay Rum
# 125  North America          1770                             Rose Hall
# 126  North America          1830                    House of Angostura
# 127  North America          1852             J. Armando Bermúdez & Co.
# 128  North America          1862                      Rhum Barbancourt
# 129  North America          1870         National Railroad of Honduras
# 130  North America          1890                          Flor de Caña
# 131  North America          1891                      HSBC El Salvador
# 132  North America          1902                           Belize Bank
# 133  North America          1904               National Bank of Panama
# 134  North America          1908          Florida Ice and Farm Company
# 135  North America          1909              The Chronicle (Dominica)
# 136  North America          1920         Corporación Multi Inversiones
# 137  North America          1929                    Cubana de Aviación
# 138  North America          1938         1st National Bank of St Lucia
# 139        Oceania          1809                        Australia Post
# 140        Oceania          1861                   Bank of New Zealand
# 141        Oceania          1869                            Fiji Times
# 142        Oceania          1991                European Trust Company
# 143  South America          1565               Casa Nacional de Moneda
# 144  South America          1621            Casa de Moneda de Colombia
# 145  South America          1660                        Hacienda Chuao
# 146  South America          1694               Casa da Moeda do Brasil
# 147  South America          1811                                 Famae
# 148  South America          1822  Bank of the Province of Buenos Aires
# 149  South America          1840                             Banks DIH
# 150  South America          1871             Banco Nacional de Bolivia
# 151  South America          1877                        Cafe Brasilero

# %%
sorted_by_cont = sorted_by_cont.groupby('continent')['year_founded'].min().reset_index()

print(sorted_by_cont)
# Out:
#        continent  year_founded
# 0         Africa          1772
# 1           Asia           578
# 2         Europe           803
# 3  North America          1534
# 4        Oceania          1809
# 5  South America          1565

# %%
oldest_business_continent = sorted_by_cont.merge(businesses_merged, on = ['continent', 'year_founded'], how= 'left')

oldest_business_continent = oldest_business_continent.drop(columns=['category', 'country_code', 'category_code'])

print(oldest_business_continent)
# Out:
#        continent  year_founded                     business    country
# 0         Africa          1772               Mauritius Post  Mauritius
# 1           Asia           578                   Kongō Gumi      Japan
# 2         Europe           803  St. Peter Stifts Kulinarium    Austria
# 3  North America          1534  La Casa de Moneda de México     Mexico
# 4        Oceania          1809               Australia Post  Australia
# 5  South America          1565      Casa Nacional de Moneda       Peru

# %% [markdown]
# #### Question 2

# %%
businesses_old_new = pd.concat([businesses, new_businesses], ignore_index=True)

merge_busi_coun = businesses_old_new.merge(countries, on = 'country_code', how = 'outer')

count_missing= merge_busi_coun[merge_busi_coun['business'].isna()]

count_missing = count_missing.drop(columns= ['business', 'year_founded', 'category_code', 'country_code', 'country'])

count_missing = count_missing['continent'].value_counts().reset_index()

print(count_missing)
# Out:
#        continent  count
# 0        Oceania     10
# 1           Asia      7
# 2  North America      5
# 3         Africa      3
# 4  South America      3
# 5         Europe      2

# %% [markdown]
# #### Question 3

# %%
oldest_by_continent_category = businesses_merged.groupby(['continent', 'category'])['year_founded'].first().reset_index()

print(oldest_by_continent_category)
# Out:
#         continent                           category  year_founded
# 0          Africa                        Agriculture             5
# 1          Africa               Aviation & Transport            14
# 2          Africa                  Banking & Finance            50
# 3          Africa  Distillers, Vintners, & Breweries            45
# 4          Africa                             Energy             1
# 5          Africa                   Food & Beverages             0
# 6          Africa         Manufacturing & Production            41
# 7          Africa                              Media            40
# 8          Africa                             Mining            19
# 9          Africa                     Postal Service            29
# 10           Asia                        Agriculture            51
# 11           Asia               Aviation & Transport            52
# 12           Asia                  Banking & Finance            69
# 13           Asia          Cafés, Restaurants & Bars            58
# 14           Asia                       Conglomerate            76
# 15           Asia                       Construction            64
# 16           Asia                            Defense            61
# 17           Asia  Distillers, Vintners, & Breweries            77
# 18           Asia                             Energy            62
# 19           Asia                   Food & Beverages            54
# 20           Asia         Manufacturing & Production            60
# 21           Asia                              Media            71
# 22           Asia                             Mining            66
# 23           Asia                     Postal Service            70
# 24           Asia                             Retail            53
# 25           Asia                 Telecommunications            82
# 26           Asia                   Tourism & Hotels           132
# 27         Europe                        Agriculture           129
# 28         Europe                  Banking & Finance           108
# 29         Europe          Cafés, Restaurants & Bars            94
# 30         Europe                     Consumer Goods           105
# 31         Europe                            Defense            98
# 32         Europe  Distillers, Vintners, & Breweries           107
# 33         Europe         Manufacturing & Production           106
# 34         Europe                              Media           113
# 35         Europe                            Medical           104
# 36         Europe                             Mining           123
# 37         Europe                     Postal Service           124
# 38         Europe                 Telecommunications            91
# 39         Europe                   Tourism & Hotels           131
# 40  North America                        Agriculture           150
# 41  North America               Aviation & Transport           143
# 42  North America                  Banking & Finance           140
# 43  North America  Distillers, Vintners, & Breweries           134
# 44  North America                   Food & Beverages           141
# 45  North America         Manufacturing & Production           145
# 46  North America                              Media           139
# 47  North America                             Retail           136
# 48  North America                   Tourism & Hotels           144
# 49        Oceania                  Banking & Finance           161
# 50        Oceania                              Media           163
# 51        Oceania                     Postal Service           160
# 52  South America                  Banking & Finance           157
# 53  South America          Cafés, Restaurants & Bars           158
# 54  South America                            Defense           154
# 55  South America                   Food & Beverages           159
# 56  South America         Manufacturing & Production           155
